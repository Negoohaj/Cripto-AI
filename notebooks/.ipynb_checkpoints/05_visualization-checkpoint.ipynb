# %% [markdown]
# ## 1. Importar Bibliotecas

# %%
# Importar bibliotecas
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import warnings
warnings.filterwarnings('ignore')

print("✅ Bibliotecas importadas com sucesso!")

# %% [markdown]
# ## 2. Carregar Dados

# %%
# Carregar dados processados
DATA_PATH = "../data/processed/crypto_processed.csv"
VIZ_DIR = "../visualizations/"

print("📂 Carregando dados...")
df = pd.read_csv(DATA_PATH, parse_dates=['Date'])

# Separar por criptomoeda
df_btc = df[df['Symbol'] == 'BTC-USD'].copy()
df_eth = df[df['Symbol'] == 'ETH-USD'].copy()

print(f"✅ Bitcoin: {len(df_btc)} registros")
print(f"✅ Ethereum: {len(df_eth)} registros")
print(f"📅 Período: {df['Date'].min()} até {df['Date'].max()}")

# %% [markdown]
# ## 3. Gráfico de Candlestick - Bitcoin

# %%
# Criar gráfico de candlestick para Bitcoin
print("📈 Criando gráfico de candlestick...")

fig_candle = go.Figure(data=[go.Candlestick(
    x=df_btc['Date'],
    open=df_btc['Open'],
    high=df_btc['High'],
    low=df_btc['Low'],
    close=df_btc['Close'],
    name='Bitcoin'
)])

fig_candle.update_layout(
    title='Bitcoin (BTC-USD) - Gráfico de Candlestick',
    yaxis_title='Preço (USD)',
    xaxis_title='Data',
    template='plotly_white',
    height=600,
    xaxis_rangeslider_visible=False
)

fig_candle.write_html(f"{VIZ_DIR}btc_candlestick.html")
fig_candle.show()

print(f"💾 Salvo: {VIZ_DIR}btc_candlestick.html")

# %% [markdown]
# ## 4. Preços com Médias Móveis - Bitcoin

# %%
# Gráfico de preços com médias móveis
print("📊 Criando gráfico de médias móveis...")

fig_ma = go.Figure()

# Preço de fechamento
fig_ma.add_trace(go.Scatter(
    x=df_btc['Date'],
    y=df_btc['Close'],
    mode='lines',
    name='Preço de Fechamento',
    line=dict(color='blue', width=2)
))

# Média móvel de 7 dias
fig_ma.add_trace(go.Scatter(
    x=df_btc['Date'],
    y=df_btc['MA7'],
    mode='lines',
    name='MA7',
    line=dict(color='orange', width=1.5)
))

# Média móvel de 30 dias
fig_ma.add_trace(go.Scatter(
    x=df_btc['Date'],
    y=df_btc['MA30'],
    mode='lines',
    name='MA30',
    line=dict(color='green', width=1.5)
))

# Média móvel de 90 dias
fig_ma.add_trace(go.Scatter(
    x=df_btc['Date'],
    y=df_btc['MA90'],
    mode='lines',
    name='MA90',
    line=dict(color='red', width=1.5)
))

fig_ma.update_layout(
    title='Bitcoin - Preço com Médias Móveis',
    xaxis_title='Data',
    yaxis_title='Preço (USD)',
    template='plotly_white',
    height=600,
    hovermode='x unified'
)

fig_ma.write_html(f"{VIZ_DIR}btc_moving_averages.html")
fig_ma.show()

print(f"💾 Salvo: {VIZ_DIR}btc_moving_averages.html")

# %% [markdown]
# ## 5. Comparação Bitcoin vs Ethereum

# %%
# Normalizar preços para comparação (base 100)
print("🔄 Normalizando preços para comparação...")

df_btc['Price_Normalized'] = (df_btc['Close'] / df_btc['Close'].iloc[0]) * 100
df_eth['Price_Normalized'] = (df_eth['Close'] / df_eth['Close'].iloc[0]) * 100

# Criar gráfico comparativo
fig_comp = go.Figure()

fig_comp.add_trace(go.Scatter(
    x=df_btc['Date'],
    y=df_btc['Price_Normalized'],
    mode='lines',
    name='Bitcoin',
    line=dict(color='orange', width=2)
))

fig_comp.add_trace(go.Scatter(
    x=df_eth['Date'],
    y=df_eth['Price_Normalized'],
    mode='lines',
    name='Ethereum',
    line=dict(color='purple', width=2)
))

fig_comp.update_layout(
    title='Bitcoin vs Ethereum - Desempenho Normalizado (Base 100)',
    xaxis_title='Data',
    yaxis_title='Preço Normalizado (Base 100)',
    template='plotly_white',
    height=600,
    hovermode='x unified'
)

fig_comp.write_html(f"{VIZ_DIR}btc_eth_comparison.html")
fig_comp.show()

print(f"💾 Salvo: {VIZ_DIR}btc_eth_comparison.html")

# %% [markdown]
# ## 6. Análise de Volume

# %%
# Gráfico de preço e volume
print("📊 Criando análise de volume...")

fig_vol = make_subplots(
    rows=2, cols=1,
    shared_xaxes=True,
    vertical_spacing=0.1,
    subplot_titles=('Preço Bitcoin', 'Volume de Negociação'),
    row_heights=[0.7, 0.3]
)

# Preço
fig_vol.add_trace(
    go.Scatter(
        x=df_btc['Date'],
        y=df_btc['Close'],
        mode='lines',
        name='Preço',
        line=dict(color='blue', width=2)
    ),
    row=1, col=1
)

# Volume
colors = ['red' if df_btc['Close'].iloc[i] < df_btc['Open'].iloc[i] else 'green' 
          for i in range(len(df_btc))]

fig_vol.add_trace(
    go.Bar(
        x=df_btc['Date'],
        y=df_btc['Volume'],
        name='Volume',
        marker_color=colors,
        opacity=0.7
    ),
    row=2, col=1
)

fig_vol.update_xaxes(title_text="Data", row=2, col=1)
fig_vol.update_yaxes(title_text="Preço (USD)", row=1, col=1)
fig_vol.update_yaxes(title_text="Volume", row=2, col=1)

fig_vol.update_layout(
    title='Bitcoin - Análise de Preço e Volume',
    template='plotly_white',
    height=800,
    showlegend=True
)

fig_vol.write_html(f"{VIZ_DIR}btc_volume_analysis.html")
fig_vol.show()

print(f"💾 Salvo: {VIZ_DIR}btc_volume_analysis.html")

# %% [markdown]
# ## 7. Análise de Volatilidade

# %%
# Gráfico de volatilidade
print("📈 Criando análise de volatilidade...")

fig_volatility = make_subplots(
    rows=2, cols=1,
    shared_xaxes=True,
    vertical_spacing=0.1,
    subplot_titles=('Retorno Diário (%)', 'Volatilidade 30 dias'),
    row_heights=[0.5, 0.5]
)

# Retorno diário
fig_volatility.add_trace(
    go.Scatter(
        x=df_btc['Date'],
        y=df_btc['Daily_Return'],
        mode='lines',
        name='Retorno Diário',
        line=dict(color='green', width=1),
        fill='tozeroy',
        fillcolor='rgba(0,255,0,0.1)'
    ),
    row=1, col=1
)

# Linha de referência zero
fig_volatility.add_hline(y=0, line_dash="dash", line_color="red", row=1, col=1)

# Volatilidade
fig_volatility.add_trace(
    go.Scatter(
        x=df_btc['Date'],
        y=df_btc['Volatility_30d'],
        mode='lines',
        name='Volatilidade 30d',
        line=dict(color='red', width=2)
    ),
    row=2, col=1
)

fig_volatility.update_xaxes(title_text="Data", row=2, col=1)
fig_volatility.update_yaxes(title_text="Retorno (%)", row=1, col=1)
fig_volatility.update_yaxes(title_text="Volatilidade (USD)", row=2, col=1)

fig_volatility.update_layout(
    title='Bitcoin - Análise de Volatilidade',
    template='plotly_white',
    height=800,
    showlegend=True
)

fig_volatility.write_html(f"{VIZ_DIR}btc_volatility_analysis.html")
fig_volatility.show()

print(f"💾 Salvo: {VIZ_DIR}btc_volatility_analysis.html")

# %% [markdown]
# ## 8. Distribuição de Retornos

# %%
# Histograma de retornos diários
print("📊 Criando distribuição de retornos...")

fig_dist = go.Figure()

# Bitcoin
fig_dist.add_trace(go.Histogram(
    x=df_btc['Daily_Return'].dropna(),
    name='Bitcoin',
    opacity=0.7,
    marker_color='orange',
    nbinsx=50
))

# Ethereum
fig_dist.add_trace(go.Histogram(
    x=df_eth['Daily_Return'].dropna(),
    name='Ethereum',
    opacity=0.7,
    marker_color='purple',
    nbinsx=50
))

fig_dist.update_layout(
    title='Distribuição de Retornos Diários - Bitcoin vs Ethereum',
    xaxis_title='Retorno Diário (%)',
    yaxis_title='Frequência',
    template='plotly_white',
    height=600,
    barmode='overlay'
)

fig_dist.write_html(f"{VIZ_DIR}returns_distribution.html")
fig_dist.show()

print(f"💾 Salvo: {VIZ_DIR}returns_distribution.html")

# %% [markdown]
# ## 9. Heatmap de Retornos Mensais

# %%
# Criar heatmap de retornos mensais para Bitcoin
print("🔥 Criando heatmap de retornos mensais...")

# Calcular retornos mensais
df_btc['Year'] = df_btc['Date'].dt.year
df_btc['Month'] = df_btc['Date'].dt.month

monthly_returns = df_btc.groupby(['Year', 'Month'])['Daily_Return'].sum().reset_index()
pivot_returns = monthly_returns.pivot(index='Year', columns='Month', values='Daily_Return')

# Criar heatmap
fig_heatmap = go.Figure(data=go.Heatmap(
    z=pivot_returns.values,
    x=['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez'],
    y=pivot_returns.index,
    colorscale='RdYlGn',
    zmid=0,
    text=pivot_returns.values,
    texttemplate='%{text:.1f}%',
    textfont={"size": 10},
    colorbar=dict(title="Retorno (%)")
))

fig_heatmap.update_layout(
    title='Bitcoin - Heatmap de Retornos Mensais',
    xaxis_title='Mês',
    yaxis_title='Ano',
    template='plotly_white',
    height=600
)

fig_heatmap.write_html(f"{VIZ_DIR}btc_monthly_returns_heatmap.html")
fig_heatmap.show()

print(f"💾 Salvo: {VIZ_DIR}btc_monthly_returns_heatmap.html")

# %% [markdown]
# ## 10. Dashboard Completo

# %%
# Criar dashboard com múltiplos gráficos
print("📊 Criando dashboard completo...")

fig_dashboard = make_subplots(
    rows=3, cols=2,
    subplot_titles=(
        'Preço Bitcoin', 'Preço Ethereum',
        'Volume Bitcoin', 'Volume Ethereum',
        'Comparação Normalizada', 'Volatilidade'
    ),
    specs=[
        [{"secondary_y": False}, {"secondary_y": False}],
        [{"secondary_y": False}, {"secondary_y": False}],
        [{"colspan": 2}, None]
    ],
    vertical_spacing=0.1,
    horizontal_spacing=0.1
)

# Bitcoin Price
fig_dashboard.add_trace(
    go.Scatter(x=df_btc['Date'], y=df_btc['Close'], name='BTC', line=dict(color='orange')),
    row=1, col=1
)

# Ethereum Price
fig_dashboard.add_trace(
    go.Scatter(x=df_eth['Date'], y=df_eth['Close'], name='ETH', line=dict(color='purple')),
    row=1, col=2
)

# Bitcoin Volume
fig_dashboard.add_trace(
    go.Bar(x=df_btc['Date'], y=df_btc['Volume'], name='Vol BTC', marker_color='lightblue'),
    row=2, col=1
)

# Ethereum Volume
fig_dashboard.add_trace(
    go.Bar(x=df_eth['Date'], y=df_eth['Volume'], name='Vol ETH', marker_color='lightpurple'),
    row=2, col=2
)

# Comparação Normalizada
fig_dashboard.add_trace(
    go.Scatter(x=df_btc['Date'], y=df_btc['Price_Normalized'], 
               name='BTC Norm', line=dict(color='orange', width=2)),
    row=3, col=1
)
fig_dashboard.add_trace(
    go.Scatter(x=df_eth['Date'], y=df_eth['Price_Normalized'], 
               name='ETH Norm', line=dict(color='purple', width=2)),
    row=3, col=1
)

fig_dashboard.update_layout(
    title_text='Dashboard de Análise de Criptomoedas',
    showlegend=True,
    template='plotly_white',
    height=1200
)

fig_dashboard.write_html(f"{VIZ_DIR}crypto_dashboard.html")
fig_dashboard.show()

print(f"💾 Salvo: {VIZ_DIR}crypto_dashboard.html")

# %% [markdown]
# ## 11. Resumo das Visualizações

# %%
print("\n" + "="*70)
print("📊 RESUMO DAS VISUALIZAÇÕES CRIADAS")
print("="*70)

visualizations = [
    "btc_candlestick.html - Gráfico de Candlestick do Bitcoin",
    "btc_moving_averages.html - Preço com Médias Móveis",
    "btc_eth_comparison.html - Comparação Bitcoin vs Ethereum",
    "btc_volume_analysis.html - Análise de Preço e Volume",
    "btc_volatility_analysis.html - Análise de Volatilidade",
    "returns_distribution.html - Distribuição de Retornos",
    "btc_monthly_returns_heatmap.html - Heatmap de Retornos Mensais",
    "crypto_dashboard.html - Dashboard Completo"
]

print("\n📁 Arquivos criados no diretório 'visualizations/':")
for i, viz in enumerate(visualizations, 1):
    print(f"   {i}. {viz}")

print("\n💡 Todas as visualizações são INTERATIVAS com Plotly!")
print("   - Zoom: Arraste o mouse sobre o gráfico")
print("   - Pan: Segure e arraste")
print("   - Reset: Clique duas vezes")
print("   - Hover: Passe o mouse sobre os pontos para ver detalhes")
print("   - Legenda: Clique para mostrar/ocultar séries")

print("\n" + "="*70)
print("✅ Visualizações finalizadas com sucesso!")
print("🎉 Projeto completo! Todos os notebooks foram executados.")
print("="*70)
